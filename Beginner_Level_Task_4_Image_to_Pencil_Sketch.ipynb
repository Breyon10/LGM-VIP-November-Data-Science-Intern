# %% [markdown]
# <a href="https://colab.research.google.com/github/Breyon10/LGM-VIP-November-Data-Science-Intern/blob/main/Beginner_Level_Task_4_Image_to_Pencil_Sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Breyon Dmello - Data Science Intern at LetsGrowMore Virtual Internship Program (November-2021)**
#
# **Beginner Level Task 4 - Image to Pencil Sketch with Python**

# %% [markdown]
# **Import the required libraries**

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# **Read the image**

# %%
image = cv2.imread('wolf.jpg')

# %% [markdown]
# **Convert to gray scale**

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# **Invert the grayscale image**

# %%
inverted_image = 255 - gray_image

# %% [markdown]
# **Blur image using Gaussian Blur Function**

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %% [markdown]
# **Invert the blurred image**

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)

# %% [markdown]
# **Original image**

# %%
plt.figure(figsize=(25,15))
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB),cmap='gray')
plt.show()

# %% [markdown]
# **Pencil sketch of the image**

# %%
plt.figure(figsize=(25,15))
plt.imshow(pencil_sketch,cmap='gray')
plt.show()
